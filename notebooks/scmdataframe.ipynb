# %% [markdown]
# # ScmDataFrame
#
# In this notebook we provide an overview of the capabilities provided by OpenSCM's `ScmDataFrame` class.
# This class is a wrapper around *pandas* [DataFrame class](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html), a high-level data structure and data analysis tool.
# By wrapping a DataFrame, we are able to make the most of the tools provided by *pandas* whilst adding our own requirements on top.

# %% [markdown]
# TODO's:
#
# - provide link to what an IAMC-format file looks like in ScmDataFrame init docstring

# %% [markdown]
# ## Imports

# %%
from openscm.scmdataframe import ScmDataFrame

# %% [markdown]
# ## Loading data
#
# `ScmDataFrame`'s can read many different data types and be loaded in many different ways.
# For a full explanation, see the docstring of `ScmDataFrame`'s `__init__` method.

# %%
# uncomment the line below and then run the cell to see the docstring
ScmDataFrame.__init__?

# %% [markdown]
# Here we load data from a file.
#
# *Note:* here we load RCP26 emissions data. This originally came from http://www.pik-potsdam.de/~mmalte/rcps/ and has since been re-written into a format which can be read by OpenSCM using the [pymagicc](https://github.com/openclimatedata/pymagicc) library. We are not currently planning on importing Pymagicc's readers into OpenSCM by default, please raise an issue if you would like us to consider doing so.

# %%
rcp26 = ScmDataFrame("rcp26_emissions.csv")

# %% [markdown]
# ## Timeseries
#
# `ScmDataFrame` is ideally suited to working with timeseries data.
# Indeed, it always stores data in 'wide' format, with each row representing one timeseries and metadata being contained in the row labels.
# The `timeseries` method allows you to easily get the data back in this format as a *pandas* `DataFrame`.

# %%
rcp26.timeseries().head()
# Out:
# time                                                               1765-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.000000
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010763
#
# time                                                               1766-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.106998
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010752
#
# time                                                               1767-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.133383
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010748
#
# time                                                               1768-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.159847
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010744
#
# time                                                               1769-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.186393
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010740
#
# time                                                               1770-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.213024
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010736
#
# time                                                               1771-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.239742
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010731
#
# time                                                               1772-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.266550
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010727
#
# time                                                               1773-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.293450
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010723
#
# time                                                               1774-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified               0.320446
#                       Emissions|C2F6  kt C2F6 / yr  unspecified               0.000000
#                       Emissions|C6F14 kt C6F14 / yr unspecified               0.000000
#                       Emissions|CCl4  kt CCl4 / yr  unspecified               0.000000
#                       Emissions|CF4   kt CF4 / yr   unspecified               0.010719
#
# time                                                               ...  \
# model scenario region variable        unit          climate_model  ...
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified    ...
#                       Emissions|C2F6  kt C2F6 / yr  unspecified    ...
#                       Emissions|C6F14 kt C6F14 / yr unspecified    ...
#                       Emissions|CCl4  kt CCl4 / yr  unspecified    ...
#                       Emissions|CF4   kt CF4 / yr   unspecified    ...
#
# time                                                               2491-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2492-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2493-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2494-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2495-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2496-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2497-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2498-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2499-01-01 00:00:00  \
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# time                                                               2500-01-01 00:00:00
# model scenario region variable        unit          climate_model
# IMAGE RCP26    World  Emissions|BC    Mt BC / yr    unspecified                 3.3578
#                       Emissions|C2F6  kt C2F6 / yr  unspecified                 0.0857
#                       Emissions|C6F14 kt C6F14 / yr unspecified                 0.0887
#                       Emissions|CCl4  kt CCl4 / yr  unspecified                 0.0000
#                       Emissions|CF4   kt CF4 / yr   unspecified                 1.0920
#
# [5 rows x 736 columns]

# %%
type(rcp26.timeseries())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Interpolation
#
# Have to store data on same time axes
# If you want to interpolate, can do so trivially
